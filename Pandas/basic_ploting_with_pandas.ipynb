# %%
import pandas as pd
import numpy as np

# %%
data_frame = pd.read_csv('dataset/combined_set.csv',)
data_frame.head(10)
# Out:
#    Year Country name ISO3 Continent  Life Ladder  Log GDP per capita  \
# 0  2007  Afghanistan  AFG      Asia     3.723590            7.168690
# 1  2008  Afghanistan  AFG      Asia     3.723590            7.168690
# 2  2009  Afghanistan  AFG      Asia     4.401778            7.333790
# 3  2010  Afghanistan  AFG      Asia     4.758381            7.386629
# 4  2011  Afghanistan  AFG      Asia     3.831719            7.415019
# 5  2012  Afghanistan  AFG      Asia     3.782938            7.517126
# 6  2013  Afghanistan  AFG      Asia     3.572100            7.522238
# 7  2014  Afghanistan  AFG      Asia     3.130896            7.516955
# 8  2015  Afghanistan  AFG      Asia     3.982855            7.500539
# 9  2016  Afghanistan  AFG      Asia     4.220169            7.497038
#
#    Social support  Healthy life expectancy at birth  \
# 0        0.450662                         50.799999
# 1        0.450662                         50.799999
# 2        0.552308                         51.200001
# 3        0.539075                         51.599998
# 4        0.521104                         51.919998
# 5        0.520637                         52.240002
# 6        0.483552                         52.560001
# 7        0.525568                         52.880001
# 8        0.528597                         53.200001
# 9        0.559072                         53.000000
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                      0.718114    0.177889                   0.881686
# 1                      0.718114    0.177889                   0.881686
# 2                      0.678896    0.200178                   0.850035
# 3                      0.600127    0.134353                   0.706766
# 4                      0.495901    0.172137                   0.731109
# 5                      0.530935    0.244273                   0.775620
# 6                      0.577955    0.070403                   0.823204
# 7                      0.508514    0.113184                   0.871242
# 8                      0.388928    0.089091                   0.880638
# 9                      0.522566    0.051365                   0.793246
#
#    Positive affect  Negative affect  Confidence in national government  \
# 0         0.517637         0.258195                           0.612072
# 1         0.517637         0.258195                           0.612072
# 2         0.583926         0.237092                           0.611545
# 3         0.618265         0.275324                           0.299357
# 4         0.611387         0.267175                           0.307386
# 5         0.710385         0.267919                           0.435440
# 6         0.620585         0.273328                           0.482847
# 7         0.531691         0.374861                           0.409048
# 8         0.553553         0.339276                           0.260557
# 9         0.564953         0.348332                           0.324990
#
#    Democratic Quality  Delivery Quality  Gapminder Life Expectancy  \
# 0           -1.929690         -1.655084                       55.2
# 1           -1.929690         -1.655084                       55.2
# 2           -2.044093         -1.635025                       55.7
# 3           -1.991810         -1.617176                       56.2
# 4           -1.919018         -1.616221                       56.7
# 5           -1.842996         -1.404078                       57.2
# 6           -1.879709         -1.403036                       57.7
# 7           -1.773257         -1.312503                       57.8
# 8           -1.844364         -1.291594                       57.9
# 9           -1.855426         -1.392713                       58.0
#
#    Gapminder Population
# 0            27300000.0
# 1            27300000.0
# 2            28000000.0
# 3            28800000.0
# 4            29700000.0
# 5            30700000.0
# 6            31700000.0
# 7            32800000.0
# 8            33700000.0
# 9            34700000.0

# %%
np.exp(data_frame[data_frame['Year']==2018]['Log GDP per capita']).plot(
    kind='hist'
)
# Out:
# 11     1798.283537
# 23    12239.201194
# 35    14156.822285
# 47     6257.154621
# 59    18214.473593
# Name: Log GDP per capita, dtype: float64

# %%
#data_frame.plot('Log GDP per capita',kind='hist',figsize=(12,8),title='hist chart')

# %% [markdown]
# ## Important Parameters
#
# There are five main parameters that I use when plotting with Pandas:
#
# **kind:** Pandas has to know what kind of plot you want to create, the following options are available ***hist, bar, barh, scatter, area, kde, line, box, hexbin, pie***.
#
# - ‘line’ : line plot (default)
# - ‘bar’ : vertical bar plot
# - ‘barh’ : horizontal bar plot
# - ‘hist’ : histogram
# - ‘box’ : boxplot
# - ‘kde’ : Kernel Density Estimation plot
# - ‘density’ : same as ‘kde’
# - ‘area’ : area plot
# - ‘pie’ : pie plot
# - ‘scatter’ : scatter plot
# - ‘hexbin’ : hexbin plot
#
#
# **figsize:** Allows overwriting the default output size of ***6 inches wide and 4 inches high***. figsize expects a tuple (e.g., figsize=(12,8) which I often use)
#
# **title:** Adds a title to the chart. Most of the time, I use this to clarify whatever is shown in the chart so that when I come back to it, I quickly can identify what's going on. ***title expects a string***.
#
# **bins:** Allows overriding the bin width for histograms. bins expects a list or listlike sequence of values (e.g., bins=np.arange(2,8,0.25))
#
# **xlim/ylim:** Allows overriding the defaults for maximum and minimum values of the axis. Both, ***xlim and ylim expect a tuple (e.g., xlim=(0,5))***
#
# Let’s quickly go through the different available types of plots.

# %% [markdown]
# ## Scatter Ploting

# %%
#data_frame.plot.scatter(data_frame['Country name']['Zimbabwe'],data_frame['life Ladder'])

data_frame[data_frame['Country name']=='Zimbabwe']
#data_frame.plot.scatter(data_frame[data_frame['Country name']=='Zimbabwe'],data_frame['Life Ladder'])
# Out:
#       Year Country name ISO3 Continent  Life Ladder  Log GDP per capita  \
# 1884  2007     Zimbabwe  ZWE    Africa     3.280247            7.313939
# 1885  2008     Zimbabwe  ZWE    Africa     3.174264            7.102516
# 1886  2009     Zimbabwe  ZWE    Africa     4.055914            7.197595
# 1887  2010     Zimbabwe  ZWE    Africa     4.681570            7.296330
# 1888  2011     Zimbabwe  ZWE    Africa     4.845642            7.418864
# 1889  2012     Zimbabwe  ZWE    Africa     4.955101            7.534424
# 1890  2013     Zimbabwe  ZWE    Africa     4.690188            7.565154
# 1891  2014     Zimbabwe  ZWE    Africa     4.184451            7.562753
# 1892  2015     Zimbabwe  ZWE    Africa     3.703191            7.556052
# 1893  2016     Zimbabwe  ZWE    Africa     3.735400            7.538829
# 1894  2017     Zimbabwe  ZWE    Africa     3.638300            7.549491
# 1895  2018     Zimbabwe  ZWE    Africa     3.616480            7.553395
#
#       Social support  Healthy life expectancy at birth  \
# 1884        0.828113                         42.860001
# 1885        0.843475                         44.139999
# 1886        0.805781                         45.419998
# 1887        0.856638                         46.700001
# 1888        0.864694                         48.119999
# 1889        0.896476                         49.540001
# 1890        0.799274                         50.959999
# 1891        0.765839                         52.380001
# 1892        0.735800                         53.799999
# 1893        0.768425                         54.400002
# 1894        0.754147                         55.000000
# 1895        0.775388                         55.599998
#
#       Freedom to make life choices  Generosity  Perceptions of corruption  \
# 1884                      0.455957   -0.061563                   0.946287
# 1885                      0.343556   -0.068002                   0.963846
# 1886                      0.411089   -0.055836                   0.930818
# 1887                      0.664718   -0.066457                   0.828361
# 1888                      0.632978   -0.062267                   0.829800
# 1889                      0.469531   -0.075712                   0.858691
# 1890                      0.575884   -0.079458                   0.830937
# 1891                      0.642034   -0.048634                   0.820217
# 1892                      0.667193   -0.097354                   0.810457
# 1893                      0.732971   -0.068105                   0.723612
# 1894                      0.752826   -0.069670                   0.751208
# 1895                      0.762675   -0.038384                   0.844209
#
#       Positive affect  Negative affect  Confidence in national government  \
# 1884         0.660861         0.264989                           0.225752
# 1885         0.630983         0.250060                           0.181594
# 1886         0.735503         0.218419                           0.285287
# 1887         0.747702         0.122150                           0.471201
# 1888         0.781189         0.210544                           0.425926
# 1889         0.669279         0.177311                           0.407084
# 1890         0.711885         0.182288                           0.527755
# 1891         0.725214         0.239111                           0.566209
# 1892         0.715079         0.178861                           0.590012
# 1893         0.737636         0.208555                           0.699344
# 1894         0.806428         0.224051                           0.682647
# 1895         0.710119         0.211726                           0.550508
#
#       Democratic Quality  Delivery Quality  Gapminder Life Expectancy  \
# 1884           -1.340245         -1.653740                       46.4
# 1885           -1.381488         -1.701545                       46.7
# 1886           -1.353181         -1.717821                       47.5
# 1887           -1.289599         -1.693678                       49.6
# 1888           -1.204545         -1.621979                       51.9
# 1889           -1.125315         -1.555728                       54.1
# 1890           -1.026085         -1.526321                       55.6
# 1891           -0.985267         -1.484067                       57.0
# 1892           -0.893078         -1.357514                       58.3
# 1893           -0.900649         -1.374650                       59.3
# 1894           -0.988153         -1.350867                       59.8
# 1895           -0.988153         -1.350867                       60.2
#
#       Gapminder Population
# 1884            13300000.0
# 1885            13600000.0
# 1886            13800000.0
# 1887            14100000.0
# 1888            14400000.0
# 1889            14700000.0
# 1890            15100000.0
# 1891            15400000.0
# 1892            15800000.0
# 1893            16200000.0
# 1894            16500000.0
# 1895            16900000.0

# %%
#data_frame.plot.scatter(data_frame[data_frame['Country name']=='Zimbabwe'],data_frame['Life Ladder'])
data_frame['Life Ladder'][:25]
# Out:
# 0     3.723590
# 1     3.723590
# 2     4.401778
# 3     4.758381
# 4     3.831719
# 5     3.782938
# 6     3.572100
# 7     3.130896
# 8     3.982855
# 9     4.220169
# 10    2.661718
# 11    2.694303
# 12    4.634252
# 13    5.059861
# 14    5.485470
# 15    5.268937
# 16    5.867422
# 17    5.510124
# 18    4.550648
# 19    4.813763
# 20    4.606651
# 21    4.511101
# 22    4.639548
# 23    5.004403
# 24    5.463567
# Name: Life Ladder, dtype: float64
