# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# load data
df = pd.read_csv('circle_employee.csv',index_col='user_id')
df.head()
# Out:
#                   name   age blood_group gender  experience  \
# user_id
# 1               Sharif   NaN          B+   male         1.5
# 2         Kanan Mahmud  28.0         NaN   Male         7.5
# 3           Md. Shakil  27.0          B-   Male         3.5
# 4         Imran Sheikh  25.0          B-   Male         1.8
# 5        Farsan Rashid  27.0          O+   Male         4.2
#
#                   designation  salary
# user_id
# 1        Jr Software Engineer   30000
# 2        Sr Software Engineer   80000
# 3           Software Engineer   45000
# 4        Jr Software Engineer   30000
# 5           Software Engineer   55000

# %% [markdown]
# # Split Dataframe

# %%
# this will split the dataframe, see result for better understanding.
salary = df['salary']
salary.head()
# Out:
# user_id
# 1    30000
# 2    80000
# 3    45000
# 4    30000
# 5    55000
# Name: salary, dtype: int64

# %%
data = df.iloc[:, :6 ] # all rows and all column except salary column
data.head()
# Out:
#                   name   age blood_group gender  experience  \
# user_id
# 1               Sharif   NaN          B+   male         1.5
# 2         Kanan Mahmud  28.0         NaN   Male         7.5
# 3           Md. Shakil  27.0          B-   Male         3.5
# 4         Imran Sheikh  25.0          B-   Male         1.8
# 5        Farsan Rashid  27.0          O+   Male         4.2
#
#                   designation
# user_id
# 1        Jr Software Engineer
# 2        Sr Software Engineer
# 3           Software Engineer
# 4        Jr Software Engineer
# 5           Software Engineer
